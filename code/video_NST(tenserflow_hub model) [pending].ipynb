# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from google.colab.patches import *

import tensorflow as tf
import tensorflow_hub as hub

# %%
sample_video="/content/drive/MyDrive/google_colab_datasets/input_videos/sunset.mp4"
sample_image="/content/drive/MyDrive/google_colab_datasets/TamilContentImages/C_image9.jpg"
sample_style="/content/drive/MyDrive/google_colab_datasets/Artworks/428771.jpg"

output_folder="/content/drive/MyDrive/google_colab_datasets/output/sample test/out_"

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %%
def load_image(path):
  img=tf.io.read_file(path)
  img=tf.image.decode_image(img,channels=3)
  img=tf.image.convert_image_dtype(img,tf.float32)
  img=img[tf.newaxis,:]
  return img

def load_frame(img):
  img=tf.convert_to_tensor(img)
  img=tf.image.convert_image_dtype(img,tf.float32)
  img=img[tf.newaxis,:]
  return img

# %%
# view style image
style_img=load_image(sample_style)
print(style_img.shape)
plt.imshow(np.squeeze(style_img))
plt.axis('off')
# Out:
# (1, 1080, 1920, 3)
# (-0.5, 1919.5, 1079.5, -0.5)

# %%
# sample testing
vid=cv2.VideoCapture(sample_video)
ret,frame=vid.read()
print(vid.get(cv2.CAP_PROP_FRAME_COUNT))
frame=load_frame(frame)
# print(frame)
plt.imshow(np.squeeze(frame))
plt.axis("off")
# for i in range(len(frame)):
#   print(i,end=" ")
# Out:
# 278.0
# (-0.5, 639.5, 359.5, -0.5)

# %%
og,frames=[],[]
def video_style(path,style_img_path):
  basename=os.path.basename(path)

  style_img=cv2.imread(style_img_path)
  vid=cv2.VideoCapture(path)

  Frame_count=int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
  W=int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
  H=int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
  FPS=int(vid.get(cv2.CAP_PROP_FPS))
  print(f"frame count:{Frame_count}\nframe width:{W}\nframe hight:{H}\nFPS:{FPS}\n")

  videowriter=cv2.VideoWriter((output_folder+basename),cv2.VideoWriter_fourcc('X', 'V', 'I', 'D'),FPS,(W,H),0)
  # out_write = cv2.VideoWriter((output_folder+basename),cv2.VideoWriter_fourcc(*'DIVX'), FPS,(W,H),0)

  style_img=cv2.resize(style_img,(W,H))
  print(style_img.shape)
  style_img=load_frame(style_img)


  for i in range(Frame_count):
    print(i,end=" ")
    ret,frame=vid.read();
    og.append(frame)
    frame=load_frame(frame)
    out_frame=model(tf.constant(frame),tf.constant(style_img))[0]
    out_frame=(np.squeeze(out_frame)*255).astype('uint8')
    # out_frame=cv2.cvtColor(out_frame,cv2.COLOR_BGR2RGB)
    frames.append(out_frame)
    # cv2_imshow(np.squeeze(out_frame))
    videowriter.write(out_frame)
    if(cv2.waitKey(1) & 0XFF==ord('q')): break
  print('\ndone')
  vid.release()
  videowriter.release()

# %%
video_style(sample_video,sample_style)
# Out:
# frame count:278
# frame width:640
# frame hight:360
# FPS:30
#
# (360, 640, 3)
# ...

# %%
print(len(frames))
# plt.imshow(temp)
# plt.imshow(frames[1])
cv2_imshow(frames[3])
# Out:
# 278
# <PIL.Image.Image image mode=RGB size=640x360>

# %%
# for i in range(len(frames)):
#   print(frames[i].shape,og[i].shape)
# Out:
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# (360, 640, 3) (360, 640, 3)
# ...
